# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv(r"C:\Users\Nida\Downloads\railway_delay_dataset.csv")

print(data.head())

print(data.describe())

sns.histplot(data["Delay_Minutes"])
plt.show()

sns.countplot(x="Weather", data=data)
plt.show()
# Out:
#    Train_No    Station  Scheduled_Hour        Day Weather  Passenger_Count  \
# 0     10103        CST               6    Tuesday   Clear             1135
# 1     10180    Byculla              21  Wednesday   Clear             1625
# 2     10093        CST              18  Wednesday   Clear              382
# 3     10015  Ghatkopar              17     Sunday   Clear             1888
# 4     10107     Kalyan              13   Saturday    Rain              687
#
#    Delay_Minutes  Delayed
# 0              2        0
# 1              4        0
# 2             22        1
# 3              2        0
# 4             12        1
#            Train_No  Scheduled_Hour  Passenger_Count  Delay_Minutes  \
# count    500.000000       500.00000       500.000000      500.00000
# mean   10102.392000        13.24800      1087.590000        9.48200
# std       57.023027         5.16797       514.207157        8.17921
# min    10001.000000         5.00000       207.000000        0.00000
# 25%    10052.750000         9.00000       674.250000        2.00000
# 50%    10104.000000        13.00000      1085.000000        8.00000
# 75%    10150.000000        18.00000      1518.500000       15.00000
# max    10199.000000        22.00000      1995.000000       41.00000
#
#           Delayed
# count  500.000000
# mean     0.548000
# std      0.498189
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000

# %%
File -> Download as -> Notebook (.ipynb)
# Out:
#   Cell In[2], line 1
#     File -> Download as -> Notebook (.ipynb)
#          ^
# SyntaxError: invalid syntax
